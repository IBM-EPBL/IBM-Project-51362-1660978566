# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
plt.hist(df['Age'])
# Out:
# (array([31., 19., 34., 29., 16., 26., 15., 10.,  6., 14.]),
#  array([18. , 23.2, 28.4, 33.6, 38.8, 44. , 49.2, 54.4, 59.6, 64.8, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Annual Income (k$)'])
# Out:
# (array([24., 22., 28., 38., 30., 36.,  8.,  6.,  4.,  4.]),
#  array([ 15. ,  27.2,  39.4,  51.6,  63.8,  76. ,  88.2, 100.4, 112.6,
#         124.8, 137. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Spending Score (1-100)'])
# Out:
# (array([16., 20., 10., 17., 35., 37., 11., 24., 14., 16.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['Spending Score (1-100)'], df['Age'])
plt.xlabel('Spending Score')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.scatter(df['Spending Score (1-100)'], df['Annual Income (k$)'])
plt.xlabel('Spending Score')
plt.ylabel('Annual Income')
# Out:
# Text(0, 0.5, 'Annual Income')

# %%
plt.scatter(df['Age'], df['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Annual Income')
# Out:
# Text(0, 0.5, 'Annual Income')

# %%
sns.countplot(data = df, x = 'Annual Income (k$)', hue = 'Gender')
sns.set(rc={'figure.figsize':(20,20)})

# %%
sns.pairplot(df)

# %%
sns.set(rc={'figure.figsize':(11,8)})
sns.boxplot(df['Age'])
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df['Gender'] = enc.fit_transform(df[['Gender']])
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
sns.boxplot(df['Annual Income (k$)'])
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
median = df.loc[df['Annual Income (k$)']<130, 'Annual Income (k$)'].median()
df.loc[df['Annual Income (k$)'] > 130, 'Annual Income (k$)'] = np.nan
df.fillna(median,inplace=True)

# %%
sns.boxplot(df['Annual Income (k$)'])
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
df_scaled = scale.fit_transform(df)
df_scaled
# Out:
# array([[-1.7234121 ,  1.12815215, -1.42456879, -1.78859775, -0.43480148],
#        [-1.70609137,  1.12815215, -1.28103541, -1.78859775,  1.19570407],
#        [-1.68877065, -0.88640526, -1.3528021 , -1.74867369, -1.71591298],
#        [-1.67144992, -0.88640526, -1.13750203, -1.74867369,  1.04041783],
#        [-1.6541292 , -0.88640526, -0.56336851, -1.70874963, -0.39597992],
#        [-1.63680847, -0.88640526, -1.20926872, -1.70874963,  1.00159627],
#        [-1.61948775, -0.88640526, -0.27630176, -1.66882558, -1.71591298],
#        [-1.60216702, -0.88640526, -1.13750203, -1.66882558,  1.70038436],
#        [-1.5848463 ,  1.12815215,  1.80493225, -1.62890152, -1.83237767],
#        [-1.56752558, -0.88640526, -0.6351352 , -1.62890152,  0.84631002],
#        [ 0.58024427, -0.88640526, -0.56336851,  0.48707349,  0.80748846],
#        [ 0.597565  ,  1.12815215, -1.3528021 ,  0.52699755, -1.75473454],
#        [ 0.61488572, -0.88640526, -0.70690189,  0.52699755,  1.46745499],
#        [ 0.63220645, -0.88640526,  0.36959845,  0.52699755, -1.67709142],
#        [ 0.64952717,  1.12815215, -0.49160182,  0.52699755,  0.88513158],
#        [ 0.6668479 ,  1.12815215, -1.42456879,  0.56692161, -1.56062674],
#        [ 0.68416862, -0.88640526, -0.27630176,  0.56692161,  0.84631002],
#        [ 0.70148935, -0.88640526,  1.30256542,  0.60684566, -1.75473454],
#        [ 0.71881007,  1.12815215, -0.49160182,  0.60684566,  1.6615628 ],
#        [ 0.73613079, -0.88640526, -0.77866858,  0.64676972, -0.39597992],
#        [ 0.75345152, -0.88640526, -0.49160182,  0.64676972,  1.42863343],
#        [ 0.77077224,  1.12815215, -0.99396865,  0.68669378, -1.48298362],
#        [ 0.78809297,  1.12815215, -0.77866858,  0.68669378,  1.81684904],
#        [ 0.80541369,  1.12815215,  0.65666521,  0.68669378, -0.55126616],
#        [ 0.82273442, -0.88640526, -0.49160182,  0.68669378,  0.92395314],
#        [ 0.84005514, -0.88640526, -0.34806844,  0.72661783, -1.09476801],
#        [ 0.85737587,  1.12815215, -0.34806844,  0.72661783,  1.54509812],
#        [ 0.87469659,  1.12815215,  0.29783176,  0.72661783, -1.28887582],
#        [ 0.89201732,  1.12815215,  0.010765  ,  0.72661783,  1.46745499],
#        [ 0.90933804, -0.88640526,  0.36959845,  0.72661783, -1.17241113],
#        [ 0.92665877, -0.88640526, -0.06100169,  0.72661783,  1.00159627],
#        [ 0.94397949, -0.88640526,  0.58489852,  0.72661783, -1.32769738],
#        [ 0.96130021, -0.88640526, -0.85043527,  0.72661783,  1.50627656],
#        [ 0.97862094,  1.12815215, -0.13276838,  0.72661783, -1.91002079],
#        [ 0.99594166, -0.88640526, -0.6351352 ,  0.72661783,  1.07923939],
#        [ 1.01326239,  1.12815215, -0.34806844,  0.72661783, -1.91002079],
#        [ 1.03058311, -0.88640526, -0.6351352 ,  0.72661783,  0.88513158],
#        [ 1.04790384, -0.88640526,  1.23079873,  0.76654189, -0.59008772],
#        [ 1.06522456, -0.88640526, -0.70690189,  0.76654189,  1.27334719],
#        [ 1.08254529,  1.12815215, -1.42456879,  0.84639   , -1.75473454],
#        [ 1.09986601, -0.88640526, -0.56336851,  0.84639   ,  1.6615628 ],
#        [ 1.11718674,  1.12815215,  0.80019859,  1.00608623, -0.93948177],
#        [ 1.13450746, -0.88640526, -0.20453507,  1.00608623,  0.96277471],
#        [ 1.15182818,  1.12815215,  0.22606507,  1.04601029, -1.17241113],
#        [ 1.16914891, -0.88640526, -0.41983513,  1.04601029,  1.73920592],
#        [ 1.18646963, -0.88640526, -0.20453507,  1.08593435, -0.90066021],
#        [ 1.20379036,  1.12815215, -0.49160182,  1.08593435,  0.49691598],
#        [ 1.22111108,  1.12815215,  0.08253169,  1.08593435, -1.44416206],
#        [ 1.23843181,  1.12815215, -0.77866858,  1.08593435,  0.96277471],
#        [ 1.25575253,  1.12815215, -0.20453507,  1.08593435, -1.56062674],
#        [ 1.27307326,  1.12815215, -0.20453507,  1.08593435,  1.62274124],
#        [ 1.29039398, -0.88640526,  0.94373197,  1.1258584 , -1.44416206],
#        [ 1.30771471, -0.88640526, -0.6351352 ,  1.1258584 ,  1.38981187],
#        [ 1.32503543,  1.12815215,  1.37433211,  1.1258584 , -1.36651894],
#        [ 1.34235616,  1.12815215, -0.85043527,  1.1258584 ,  0.72984534],
#        [ 1.35967688,  1.12815215,  1.4460988 ,  1.32547869, -1.4053405 ],
#        [ 1.3769976 ,  1.12815215, -0.27630176,  1.32547869,  1.54509812],
#        [ 1.39431833, -0.88640526, -0.13276838,  1.48517491, -0.7065524 ],
#        [ 1.41163905, -0.88640526, -0.49160182,  1.48517491,  1.38981187],
#        [ 1.42895978,  1.12815215,  0.51313183,  1.52509897, -1.36651894],
#        [ 1.4462805 , -0.88640526, -0.70690189,  1.52509897,  1.46745499],
#        [ 1.46360123, -0.88640526,  0.15429838,  1.56502303, -0.43480148],
#        [ 1.48092195,  1.12815215, -0.6351352 ,  1.56502303,  1.81684904],
#        [ 1.49824268, -0.88640526,  1.08726535,  1.64487114, -1.01712489],
#        [ 1.5155634 ,  1.12815215, -0.77866858,  1.64487114,  0.69102378],
#        [ 1.53288413, -0.88640526,  0.15429838,  1.72471925, -1.28887582],
#        [ 1.55020485, -0.88640526, -0.20453507,  1.72471925,  1.35099031],
#        [ 1.56752558, -0.88640526, -0.34806844,  1.72471925, -1.05594645],
#        [ 1.5848463 , -0.88640526, -0.49160182,  1.72471925,  0.72984534],
#        [ 1.60216702,  1.12815215, -0.41983513,  2.12395982, -1.63826986],
#        [ 1.61948775, -0.88640526, -0.06100169,  2.12395982,  1.58391968],
#        [ 1.63680847, -0.88640526,  0.58489852,  2.40342822, -1.32769738],
#        [ 1.6541292 , -0.88640526, -0.27630176,  2.40342822,  1.11806095],
#        [ 1.67144992, -0.88640526,  0.44136514,  2.64297256, -0.86183865],
#        [ 1.68877065,  1.12815215, -0.49160182,  2.64297256,  0.92395314],
#        [ 1.70609137,  1.12815215, -0.49160182,  0.04790887, -1.25005425],
#        [ 1.7234121 ,  1.12815215, -0.6351352 ,  0.04790887,  1.27334719]])

# %%
df.shape, df_scaled.shape
# Out:
# ((200, 5), (200, 5))

# %%
from sklearn.cluster import KMeans  
wcss_list= [] 
x = df
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++')  
    kmeans.fit(x)  
    wcss_list.append(kmeans.inertia_)  
plt.plot(range(1, 11), wcss_list)  
plt.title('The Elobw Method Graph')  
plt.xlabel('Number of clusters(k)')  
plt.ylabel('wcss_list')
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Text(0, 0.5, 'wcss_list')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(2)
df = pca.fit_transform(x)
df.shape
# Out:
# (200, 2)

# %%
kmeans = KMeans(n_clusters= 5)
label = kmeans.fit_predict(df)
print(label)
# Out:
# C:\Users\Roshni\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0 4 0
#  4 0 4 0 4 0 4 0 4 0 0 0 0 0 4 0 0 0 0 0 0 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 1 2 1 2 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1
#  3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3 1 3
#  1 3 1 3 1 3 1 3 1 3 1 3 1 3 1]

# %%
u_labels = np.unique(label)
centroids = kmeans.cluster_centers_
for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'black')
plt.legend()
